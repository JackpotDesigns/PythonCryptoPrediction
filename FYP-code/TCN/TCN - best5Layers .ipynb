# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.utils import plot_model
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential 
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop , Adam
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error , mean_absolute_error , mean_absolute_percentage_error
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import LSTM , Dense , Dropout , GRU , Concatenate , Input , Conv1D , InputLayer , Flatten
from tensorflow.keras import models
from tensorflow.keras.callbacks import EarlyStopping
import math

# %%
df_btc = pd.read_csv("BTC_1h_data.csv")

# %% [markdown]
# <Strong> Grabbing the closing price (univariate) </Strong>

# %%
btc_data = df_btc.values[:, 4 ,].astype(float)

# %% [markdown]
# <Strong> Scaling the data  </Strong>

# %%
percTrain = 70
percVal = 20

# %%
scaler = MinMaxScaler()
    
onePercent = len(btc_data) // 100
numberTraining = onePercent * percTrain

reshaped_data = btc_data.reshape(-1,1)

#Just scaling on training data otherwise it would be leakage
scaler.fit(reshaped_data[:numberTraining])
scaled_btc = scaler.transform(reshaped_data)

# %% [markdown]
# <Strong> Hyper-parameters </Strong>

# %%
# Hyper Parameters 

# How many hidden layers we should have 
# Learning rate
# Kernel Size
# Window Size
#Filters

window_length = 72
features = 1

# %% [markdown]
# <Strong> Creating Matrix in Sliding window form <Strong>

# %%
def sliding_window(elements, window_size):
    
    data = [] 
    targets = []
    
    if len(elements) <= window_size:
        return elements
    
    for i in range(len(elements) - window_size ):
        
        data.append(elements[i:i+window_size])
        targets.append(elements[i+window_size])
        
    return np.array(data) , np.array(targets)

sliding_winda_btc = sliding_window(scaled_btc , window_length)

# %% [markdown]
# <Strong> Splitting the data into train , val , test </Strong>

# %%
# Splitting the data after creating the sliding window data
def splitting_train_test(data):
        
    onePercent = len(data[1]) // 100
    
    numberTraining = onePercent * percTrain
    numberValidation = onePercent * percVal
    
    trainingData = data[0][:numberTraining] , data[1][:numberTraining]
    validationData = data[0][numberTraining : numberTraining + numberValidation] , data[1][numberTraining : numberTraining + numberValidation]
    testData = data[0][numberTraining + numberValidation:] , data[1][numberTraining + numberValidation:] 
    
    #Returning tuples of (sliding-window , target_values)
    return trainingData , validationData , testData

btc_train , btc_val , btc_test = splitting_train_test(sliding_winda_btc)

# %% [markdown]
# <Strong> Best 5-Layer Model with <i> dilation_rate = 2 </i> and <i> kernel_size = 2 </i> </Strong>

# %%
model = models.Sequential()

model.add(Conv1D(filters= 32, kernel_size=2, activation='relu', input_shape=(window_length, 1), dilation_rate=1 , padding = 'causal'))
model.add(Conv1D(filters= 32, kernel_size=2, activation='relu' , padding = 'causal', dilation_rate=2))
model.add(Conv1D(filters= 32 , kernel_size=2, activation='relu' , padding = 'causal' , dilation_rate=4))
model.add(Conv1D(filters= 32 , kernel_size=2, activation='relu' , padding = 'causal' , dilation_rate=8))
model.add(Conv1D(filters= 32 , kernel_size=2, activation='relu' , padding = 'causal' , dilation_rate=16))

model.add(Flatten())

model.add(Dense(16, activation='relu'))

model.add(Dense(1))

model.summary()

opt = Adam(learning_rate=0.004)
model.compile(optimizer=opt , loss = 'mse')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 72, 32)            96
#
#  conv1d_6 (Conv1D)           (None, 72, 32)            2080
#
#  conv1d_7 (Conv1D)           (None, 72, 32)            2080
#
#  conv1d_8 (Conv1D)           (None, 72, 32)            2080
#
#  conv1d_9 (Conv1D)           (None, 72, 32)            2080
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 16)                36880
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 45,313
# Trainable params: 45,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlyStopping = EarlyStopping(monitor = 'val_loss' , patience = 30 , mode = 'min' , verbose = 1)
history = model.fit(btc_train[0] , btc_train[1] , validation_data = btc_val  , batch_size = 512  , epochs =300 , verbose = 1 , callbacks=[earlyStopping])
num_epochs = earlyStopping.stopped_epoch
# Out:
# Epoch 1/300
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0111 - val_loss: 0.0166
# Epoch 2/300
# 54/54 [==============================] - 3s 63ms/step - loss: 6.9686e-04 - val_loss: 0.0199
# Epoch 3/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.2065e-04 - val_loss: 0.0146
# Epoch 4/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.3230e-04 - val_loss: 0.0191
# Epoch 5/300
# 54/54 [==============================] - 4s 79ms/step - loss: 4.5150e-04 - val_loss: 0.0104
# Epoch 6/300
# 54/54 [==============================] - 3s 61ms/step - loss: 3.7914e-04 - val_loss: 0.0196
# Epoch 7/300
# 54/54 [==============================] - 3s 63ms/step - loss: 3.2830e-04 - val_loss: 0.0351
# Epoch 8/300
# 54/54 [==============================] - 3s 63ms/step - loss: 2.8435e-04 - val_loss: 0.0678
# Epoch 9/300
# 54/54 [==============================] - 3s 62ms/step - loss: 2.2779e-04 - val_loss: 0.0569
# Epoch 10/300
# 54/54 [==============================] - 3s 61ms/step - loss: 1.9101e-04 - val_loss: 0.0770
# Epoch 11/300
# 54/54 [==============================] - 3s 61ms/step - loss: 1.5697e-04 - val_loss: 0.0498
# Epoch 12/300
# 54/54 [==============================] - 3s 61ms/step - loss: 1.5056e-04 - val_loss: 0.0079
# Epoch 13/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.5117e-04 - val_loss: 0.0100
# Epoch 14/300
# 54/54 [==============================] - 3s 63ms/step - loss: 1.2742e-04 - val_loss: 0.0074
# Epoch 15/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.5730e-04 - val_loss: 0.0166
# Epoch 16/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.1810e-04 - val_loss: 0.0062
# Epoch 17/300
# 54/54 [==============================] - 3s 63ms/step - loss: 1.3435e-04 - val_loss: 0.0041
# Epoch 18/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.2365e-04 - val_loss: 0.0064
# Epoch 19/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.2104e-04 - val_loss: 0.0136
# Epoch 20/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.1297e-04 - val_loss: 0.0039
# Epoch 21/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.0378e-04 - val_loss: 0.0119
# Epoch 22/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.3036e-04 - val_loss: 0.0057
# Epoch 23/300
# 54/54 [==============================] - 4s 78ms/step - loss: 1.1047e-04 - val_loss: 0.0127
# Epoch 24/300
# 54/54 [==============================] - 3s 63ms/step - loss: 9.7420e-05 - val_loss: 0.0093
# Epoch 25/300
# 54/54 [==============================] - 3s 63ms/step - loss: 8.5156e-05 - val_loss: 0.0100
# Epoch 26/300
# 54/54 [==============================] - 3s 64ms/step - loss: 9.7222e-05 - val_loss: 0.0044
# Epoch 27/300
# 54/54 [==============================] - 3s 63ms/step - loss: 1.0397e-04 - val_loss: 0.0029
# Epoch 28/300
# 54/54 [==============================] - 3s 62ms/step - loss: 8.3753e-05 - val_loss: 0.0025
# Epoch 29/300
# 54/54 [==============================] - 3s 62ms/step - loss: 8.3689e-05 - val_loss: 0.0043
# Epoch 30/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.1009e-04 - val_loss: 0.0046
# Epoch 31/300
# 54/54 [==============================] - 3s 61ms/step - loss: 1.1590e-04 - val_loss: 0.0027
# Epoch 32/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.7857e-05 - val_loss: 0.0022
# Epoch 33/300
# 54/54 [==============================] - 3s 62ms/step - loss: 8.8739e-05 - val_loss: 0.0022
# Epoch 34/300
# 54/54 [==============================] - 3s 62ms/step - loss: 7.4278e-05 - val_loss: 0.0099
# Epoch 35/300
# 54/54 [==============================] - 3s 62ms/step - loss: 9.5214e-05 - val_loss: 0.0020
# Epoch 36/300
# 54/54 [==============================] - 3s 62ms/step - loss: 7.5059e-05 - val_loss: 0.0065
# Epoch 37/300
# 54/54 [==============================] - 3s 62ms/step - loss: 8.7918e-05 - val_loss: 0.0020
# Epoch 38/300
# 54/54 [==============================] - 3s 61ms/step - loss: 7.2708e-05 - val_loss: 0.0027
# Epoch 39/300
# 54/54 [==============================] - 3s 61ms/step - loss: 8.0188e-05 - val_loss: 0.0042
# Epoch 40/300
# 54/54 [==============================] - 4s 77ms/step - loss: 9.7685e-05 - val_loss: 0.0013
# Epoch 41/300
# 54/54 [==============================] - 3s 62ms/step - loss: 9.0426e-05 - val_loss: 0.0108
# Epoch 42/300
# 54/54 [==============================] - 3s 62ms/step - loss: 8.3976e-05 - val_loss: 0.0016
# Epoch 43/300
# 54/54 [==============================] - 3s 61ms/step - loss: 7.5896e-05 - val_loss: 0.0012
# Epoch 44/300
# 54/54 [==============================] - 3s 61ms/step - loss: 7.4786e-05 - val_loss: 0.0029
# Epoch 45/300
# 54/54 [==============================] - 3s 61ms/step - loss: 8.7513e-05 - val_loss: 0.0113
# Epoch 46/300
# 54/54 [==============================] - 3s 61ms/step - loss: 8.8875e-05 - val_loss: 0.0016
# Epoch 47/300
# 54/54 [==============================] - 3s 61ms/step - loss: 7.9831e-05 - val_loss: 0.0036
# Epoch 48/300
# 54/54 [==============================] - 3s 61ms/step - loss: 6.0451e-05 - val_loss: 0.0011
# Epoch 49/300
# 54/54 [==============================] - 3s 61ms/step - loss: 7.0755e-05 - val_loss: 0.0012
# Epoch 50/300
# 54/54 [==============================] - 3s 61ms/step - loss: 6.8655e-05 - val_loss: 0.0112
# Epoch 51/300
# 54/54 [==============================] - 3s 61ms/step - loss: 6.2321e-05 - val_loss: 0.0016
# Epoch 52/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.0892e-05 - val_loss: 0.0011
# Epoch 53/300
# 54/54 [==============================] - 3s 63ms/step - loss: 7.0932e-05 - val_loss: 0.0011
# Epoch 54/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.5495e-05 - val_loss: 0.0066
# Epoch 55/300
# 54/54 [==============================] - 3s 63ms/step - loss: 1.0378e-04 - val_loss: 0.0010
# Epoch 56/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.9610e-05 - val_loss: 0.0012
# Epoch 57/300
# 54/54 [==============================] - 3s 62ms/step - loss: 7.7963e-05 - val_loss: 0.0031
# Epoch 58/300
# 54/54 [==============================] - 4s 77ms/step - loss: 6.5926e-05 - val_loss: 0.0087
# Epoch 59/300
# 54/54 [==============================] - 3s 62ms/step - loss: 7.6553e-05 - val_loss: 0.0051
# Epoch 60/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.6040e-05 - val_loss: 0.0034
# Epoch 61/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.9606e-05 - val_loss: 0.0013
# Epoch 62/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.4768e-05 - val_loss: 0.0024
# Epoch 63/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.5663e-05 - val_loss: 0.0018
# Epoch 64/300
# 54/54 [==============================] - 3s 62ms/step - loss: 4.9545e-05 - val_loss: 0.0011
# Epoch 65/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.1300e-05 - val_loss: 0.0014
# Epoch 66/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.4439e-05 - val_loss: 0.0055
# Epoch 67/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.1537e-05 - val_loss: 0.0038
# Epoch 68/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.0632e-05 - val_loss: 0.0048
# Epoch 69/300
# 54/54 [==============================] - 3s 61ms/step - loss: 9.6260e-05 - val_loss: 0.0016
# Epoch 70/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.8942e-05 - val_loss: 0.0014
# Epoch 71/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.9914e-05 - val_loss: 0.0012
# Epoch 72/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.1669e-05 - val_loss: 0.0012
# Epoch 73/300
# 54/54 [==============================] - 3s 62ms/step - loss: 4.7066e-05 - val_loss: 0.0025
# Epoch 74/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.3877e-05 - val_loss: 0.0040
# Epoch 75/300
# 54/54 [==============================] - 3s 62ms/step - loss: 8.7367e-05 - val_loss: 0.0015
# Epoch 76/300
# 54/54 [==============================] - 4s 77ms/step - loss: 4.9178e-05 - val_loss: 0.0097
# Epoch 77/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.8736e-05 - val_loss: 0.0049
# Epoch 78/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.3423e-05 - val_loss: 0.0067
# Epoch 79/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.3583e-05 - val_loss: 0.0011
# Epoch 80/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.0399e-05 - val_loss: 9.7588e-04
# Epoch 81/300
# 54/54 [==============================] - 3s 61ms/step - loss: 1.1170e-04 - val_loss: 0.0058
# Epoch 82/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.0626e-04 - val_loss: 0.0011
# Epoch 83/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.9045e-05 - val_loss: 0.0050
# Epoch 84/300
# 54/54 [==============================] - 3s 61ms/step - loss: 6.8563e-05 - val_loss: 0.0015
# Epoch 85/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.8695e-05 - val_loss: 0.0026
# Epoch 86/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.8576e-05 - val_loss: 0.0038
# Epoch 87/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.2823e-05 - val_loss: 0.0015
# Epoch 88/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.0407e-05 - val_loss: 0.0025
# Epoch 89/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.4890e-05 - val_loss: 0.0023
# Epoch 90/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.2732e-05 - val_loss: 0.0078
# Epoch 91/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.0732e-05 - val_loss: 0.0073
# Epoch 92/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.6463e-05 - val_loss: 0.0024
# Epoch 93/300
# 54/54 [==============================] - 4s 68ms/step - loss: 5.7122e-05 - val_loss: 0.0012
# Epoch 94/300
# 54/54 [==============================] - 4s 68ms/step - loss: 7.7673e-05 - val_loss: 0.0018
# Epoch 95/300
# 54/54 [==============================] - 3s 61ms/step - loss: 8.9115e-05 - val_loss: 0.0032
# Epoch 96/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.0013e-04 - val_loss: 0.0056
# Epoch 97/300
# 54/54 [==============================] - 3s 61ms/step - loss: 3.9914e-05 - val_loss: 0.0011
# Epoch 98/300
# 54/54 [==============================] - 3s 61ms/step - loss: 3.7301e-05 - val_loss: 0.0012
# Epoch 99/300
# 54/54 [==============================] - 3s 61ms/step - loss: 3.7376e-05 - val_loss: 0.0037
# Epoch 100/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.7096e-05 - val_loss: 0.0012
# Epoch 101/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.0896e-05 - val_loss: 0.0018
# Epoch 102/300
# 54/54 [==============================] - 3s 62ms/step - loss: 1.0778e-04 - val_loss: 0.0024
# Epoch 103/300
# 54/54 [==============================] - 3s 62ms/step - loss: 4.6177e-05 - val_loss: 0.0028
# Epoch 104/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.9420e-05 - val_loss: 0.0114
# Epoch 105/300
# 54/54 [==============================] - 3s 61ms/step - loss: 3.7485e-05 - val_loss: 0.0016
# Epoch 106/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.8527e-05 - val_loss: 0.0025
# Epoch 107/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.8402e-05 - val_loss: 0.0016
# Epoch 108/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.0640e-05 - val_loss: 9.7353e-04
# Epoch 109/300
# 54/54 [==============================] - 3s 62ms/step - loss: 6.2440e-05 - val_loss: 0.0054
# Epoch 110/300
# 54/54 [==============================] - 3s 61ms/step - loss: 3.7200e-05 - val_loss: 0.0014
# Epoch 111/300
# 54/54 [==============================] - 4s 77ms/step - loss: 5.0834e-05 - val_loss: 0.0184
# Epoch 112/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.2753e-05 - val_loss: 0.0035
# Epoch 113/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.5904e-05 - val_loss: 0.0020
# Epoch 114/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.0915e-05 - val_loss: 0.0011
# Epoch 115/300
# 54/54 [==============================] - 3s 61ms/step - loss: 7.1241e-05 - val_loss: 0.0010
# Epoch 116/300
# 54/54 [==============================] - 3s 63ms/step - loss: 3.5197e-05 - val_loss: 0.0021
# Epoch 117/300
# 54/54 [==============================] - 3s 63ms/step - loss: 5.5710e-05 - val_loss: 0.0073
# Epoch 118/300
# 54/54 [==============================] - 3s 63ms/step - loss: 5.0867e-05 - val_loss: 0.0018
# Epoch 119/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.7916e-05 - val_loss: 0.0013
# Epoch 120/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.9661e-05 - val_loss: 0.0032
# Epoch 121/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.4214e-05 - val_loss: 0.0040
# Epoch 122/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.8272e-05 - val_loss: 0.0050
# Epoch 123/300
# 54/54 [==============================] - 3s 61ms/step - loss: 5.0614e-05 - val_loss: 0.0013
# Epoch 124/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.5434e-05 - val_loss: 0.0011
# Epoch 125/300
# 54/54 [==============================] - 3s 62ms/step - loss: 3.8174e-05 - val_loss: 0.0012
# Epoch 126/300
# 54/54 [==============================] - 3s 61ms/step - loss: 4.4398e-05 - val_loss: 0.0029
# Epoch 127/300
# 54/54 [==============================] - 3s 63ms/step - loss: 5.3541e-05 - val_loss: 0.0013
# Epoch 128/300
# 54/54 [==============================] - 3s 63ms/step - loss: 3.9545e-05 - val_loss: 0.0021
# Epoch 129/300
# 54/54 [==============================] - 4s 78ms/step - loss: 4.1306e-05 - val_loss: 0.0085
# Epoch 130/300
# 54/54 [==============================] - 3s 63ms/step - loss: 6.0808e-05 - val_loss: 0.0011
# Epoch 131/300
# 54/54 [==============================] - 3s 62ms/step - loss: 5.3175e-05 - val_loss: 0.0010
# Epoch 132/300
# 54/54 [==============================] - 3s 64ms/step - loss: 6.1259e-05 - val_loss: 0.0013
# Epoch 133/300
# 54/54 [==============================] - 3s 64ms/step - loss: 5.0546e-05 - val_loss: 0.0010
# Epoch 134/300
# 54/54 [==============================] - 3s 64ms/step - loss: 5.9525e-05 - val_loss: 0.0041
# Epoch 135/300
# 54/54 [==============================] - 3s 63ms/step - loss: 4.5732e-05 - val_loss: 0.0058
# Epoch 136/300
# 54/54 [==============================] - 3s 63ms/step - loss: 4.0476e-05 - val_loss: 0.0142
# Epoch 137/300
# 54/54 [==============================] - 3s 63ms/step - loss: 6.2694e-05 - val_loss: 0.0028
# Epoch 138/300
# 54/54 [==============================] - 3s 64ms/step - loss: 6.7262e-05 - val_loss: 0.0081
# Epoch 138: early stopping

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
#plt.ylim([0,0.01])
plt.show()
