# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.utils import plot_model
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential 
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop , Adam
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error , mean_absolute_error , mean_absolute_percentage_error
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import LSTM , Dense , Dropout , GRU , Concatenate , Input , Conv1D , InputLayer , Flatten
from tensorflow.keras import models
from tensorflow.keras.callbacks import EarlyStopping
import math

# %%
df_btc = pd.read_csv("BTC_1h_data.csv")

# %% [markdown]
# <Strong> Grabbing the closing price (univariate) </Strong>

# %%
btc_data = df_btc.values[:, 4 ,].astype(float)

# %% [markdown]
# <Strong> Scaling the data  </Strong>

# %%
percTrain = 70
percVal = 20

# %%
scaler = MinMaxScaler()
    
onePercent = len(btc_data) // 100
numberTraining = onePercent * percTrain

reshaped_data = btc_data.reshape(-1,1)

#Just scaling on training data otherwise it would be leakage
scaler.fit(reshaped_data[:numberTraining])
scaled_btc = scaler.transform(reshaped_data)

# %% [markdown]
# <Strong> Hyper-parameters </Strong>

# %%
# Hyper Parameters 

# How many hidden layers we should have 
# Learning rate
# Kernel Size
# Window Size
#Filters

window_length = 48
features = 1

# %% [markdown]
# <Strong> Creating Matrix in Sliding window form <Strong>

# %%
def sliding_window(elements, window_size):
    
    data = [] 
    targets = []
    
    if len(elements) <= window_size:
        return elements
    
    for i in range(len(elements) - window_size ):
        
        data.append(elements[i:i+window_size])
        targets.append(elements[i+window_size])
        
    return np.array(data) , np.array(targets)

sliding_winda_btc = sliding_window(scaled_btc , window_length)

# %% [markdown]
# <Strong> Splitting the data into train , val , test </Strong>

# %%
# Splitting the data after creating the sliding window data
def splitting_train_test(data):
        
    onePercent = len(data[1]) // 100
    
    numberTraining = onePercent * percTrain
    numberValidation = onePercent * percVal
    
    trainingData = data[0][:numberTraining] , data[1][:numberTraining]
    validationData = data[0][numberTraining : numberTraining + numberValidation] , data[1][numberTraining : numberTraining + numberValidation]
    testData = data[0][numberTraining + numberValidation:] , data[1][numberTraining + numberValidation:] 
    
    #Returning tuples of (sliding-window , target_values)
    return trainingData , validationData , testData

btc_train , btc_val , btc_test = splitting_train_test(sliding_winda_btc)

# %% [markdown]
# <Strong> The number of layers while changing dilation_base , kernel_size or window_size. </Strong>

# %%
def getLayers(dilation_rate , window_size , kernel_size):
    
    top = (dilation_rate - 1) * (window_size - 1)
    bottom = (kernel_size - 1) 
    
    division = (top / bottom) + 1 
    log = math.ceil(math.log(division , dilation_rate))
    
    
    # This inequality must hold true for full coverage
    
    first = 1 + (kernel_size - 1)
    second = (dilation_rate ** log ) - 1
    third = dilation_rate - 1
    
    inequality = (second / third) * first
    
    if ( (kernel_size < dilation_rate) or (inequality < window_size) ):
        print("not going to have full coverage")
        return False
    
    else:
        print("layers =" , log , "dilation rate =" , dilation_rate , "kernel size =" , kernel_size , )
        return log , dilation_rate , kernel_size

getLayers( 2 , 24 , 4)
# Out:
# layers = 4 dilation rate = 2 kernel size = 4
# (4, 2, 4)

# %%
model = models.Sequential()

model.add(Conv1D(filters= 16, kernel_size=3, activation='relu', input_shape=(window_length, 1), dilation_rate=1 , padding = 'causal'))
model.add(Conv1D(filters= 16, kernel_size=3, activation='relu' , padding = 'causal', dilation_rate=3))
model.add(Conv1D(filters= 16 , kernel_size=3, activation='relu' , padding = 'causal' , dilation_rate=9))
model.add(Conv1D(filters= 16 , kernel_size=3, activation='relu' , padding = 'causal' , dilation_rate=27))

model.add(Flatten())

#model.add(Dropout(hp_dropout))

model.add(Dense(16, activation='relu'))

model.add(Dense(1))

model.summary()

opt = Adam(learning_rate=0.0005)
model.compile(optimizer=opt , loss = 'mse')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 72, 16)            64
#
#  conv1d_9 (Conv1D)           (None, 72, 16)            784
#
#  conv1d_10 (Conv1D)          (None, 72, 16)            784
#
#  conv1d_11 (Conv1D)          (None, 72, 16)            784
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 16)                18448
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 20,881
# Trainable params: 20,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlyStopping = EarlyStopping(monitor = 'val_loss' , patience = 30 , mode = 'min' , verbose = 1)
history = model.fit(btc_train[0] , btc_train[1] , validation_data = btc_val  , batch_size = 512  , epochs =300 , verbose = 1 , callbacks=[earlyStopping])
num_epochs = earlyStopping.stopped_epoch
# Out:
# Epoch 1/300
# 54/54 [==============================] - 2s 14ms/step - loss: 0.0123 - val_loss: 0.0475
# Epoch 2/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.6608e-04 - val_loss: 0.0233
# Epoch 3/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.2268e-04 - val_loss: 0.0222
# Epoch 4/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.0387e-04 - val_loss: 0.0225
# Epoch 5/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.7799e-04 - val_loss: 0.0213
# Epoch 6/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.4726e-04 - val_loss: 0.0220
# Epoch 7/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.1551e-04 - val_loss: 0.0191
# Epoch 8/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.7685e-04 - val_loss: 0.0208
# Epoch 9/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.3139e-04 - val_loss: 0.0171
# Epoch 10/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.7972e-04 - val_loss: 0.0149
# Epoch 11/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.1495e-04 - val_loss: 0.0144
# Epoch 12/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.3382e-04 - val_loss: 0.0122
# Epoch 13/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4790e-04 - val_loss: 0.0101
# Epoch 14/300
# 54/54 [==============================] - 0s 7ms/step - loss: 2.6779e-04 - val_loss: 0.0077
# Epoch 15/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.9239e-04 - val_loss: 0.0139
# Epoch 16/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.6276e-04 - val_loss: 0.0079
# Epoch 17/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.4988e-04 - val_loss: 0.0077
# Epoch 18/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.4322e-04 - val_loss: 0.0109
# Epoch 19/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.3057e-04 - val_loss: 0.0134
# Epoch 20/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.2320e-04 - val_loss: 0.0082
# Epoch 21/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.1898e-04 - val_loss: 0.0089
# Epoch 22/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.1196e-04 - val_loss: 0.0100
# Epoch 23/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.0965e-04 - val_loss: 0.0071
# Epoch 24/300
# 54/54 [==============================] - 0s 7ms/step - loss: 1.0075e-04 - val_loss: 0.0063
# Epoch 25/300
# 54/54 [==============================] - 0s 7ms/step - loss: 9.7704e-05 - val_loss: 0.0066
# Epoch 26/300
# 54/54 [==============================] - 0s 7ms/step - loss: 9.4279e-05 - val_loss: 0.0072
# Epoch 27/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.9211e-05 - val_loss: 0.0069
# Epoch 28/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.6438e-05 - val_loss: 0.0060
# Epoch 29/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.3524e-05 - val_loss: 0.0045
# Epoch 30/300
# 54/54 [==============================] - 0s 7ms/step - loss: 8.1387e-05 - val_loss: 0.0049
# Epoch 31/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.6703e-05 - val_loss: 0.0069
# Epoch 32/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.5483e-05 - val_loss: 0.0059
# Epoch 33/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.1401e-05 - val_loss: 0.0050
# Epoch 34/300
# 54/54 [==============================] - 0s 7ms/step - loss: 7.1183e-05 - val_loss: 0.0047
# Epoch 35/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.7424e-05 - val_loss: 0.0043
# Epoch 36/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.6121e-05 - val_loss: 0.0050
# Epoch 37/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.3621e-05 - val_loss: 0.0051
# Epoch 38/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.3043e-05 - val_loss: 0.0034
# Epoch 39/300
# 54/54 [==============================] - 0s 7ms/step - loss: 6.0062e-05 - val_loss: 0.0038
# Epoch 40/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.9338e-05 - val_loss: 0.0043
# Epoch 41/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.8059e-05 - val_loss: 0.0045
# Epoch 42/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.7752e-05 - val_loss: 0.0030
# Epoch 43/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.9090e-05 - val_loss: 0.0058
# Epoch 44/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.4765e-05 - val_loss: 0.0036
# Epoch 45/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.2791e-05 - val_loss: 0.0050
# Epoch 46/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.3796e-05 - val_loss: 0.0034
# Epoch 47/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.1983e-05 - val_loss: 0.0036
# Epoch 48/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.0841e-05 - val_loss: 0.0024
# Epoch 49/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.0615e-05 - val_loss: 0.0032
# Epoch 50/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.0554e-05 - val_loss: 0.0030
# Epoch 51/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.8270e-05 - val_loss: 0.0047
# Epoch 52/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.7289e-05 - val_loss: 0.0026
# Epoch 53/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.6214e-05 - val_loss: 0.0030
# Epoch 54/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.6776e-05 - val_loss: 0.0029
# Epoch 55/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.1546e-05 - val_loss: 0.0022
# Epoch 56/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.7995e-05 - val_loss: 0.0036
# Epoch 57/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.3560e-05 - val_loss: 0.0035
# Epoch 58/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.4387e-05 - val_loss: 0.0038
# Epoch 59/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.3939e-05 - val_loss: 0.0041
# Epoch 60/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.3279e-05 - val_loss: 0.0027
# Epoch 61/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.1669e-05 - val_loss: 0.0039
# Epoch 62/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.1232e-05 - val_loss: 0.0042
# Epoch 63/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.5778e-05 - val_loss: 0.0035
# Epoch 64/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.0408e-05 - val_loss: 0.0034
# Epoch 65/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.1297e-05 - val_loss: 0.0033
# Epoch 66/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.0918e-05 - val_loss: 0.0037
# Epoch 67/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.2945e-05 - val_loss: 0.0038
# Epoch 68/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.2653e-05 - val_loss: 0.0021
# Epoch 69/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.0802e-05 - val_loss: 0.0022
# Epoch 70/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.0646e-05 - val_loss: 0.0032
# Epoch 71/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.8362e-05 - val_loss: 0.0044
# Epoch 72/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.4609e-05 - val_loss: 0.0035
# Epoch 73/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7809e-05 - val_loss: 0.0041
# Epoch 74/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.8914e-05 - val_loss: 0.0032
# Epoch 75/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.1563e-05 - val_loss: 0.0021
# Epoch 76/300
# 54/54 [==============================] - 0s 7ms/step - loss: 5.3474e-05 - val_loss: 0.0045
# Epoch 77/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.9884e-05 - val_loss: 0.0027
# Epoch 78/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7671e-05 - val_loss: 0.0024
# Epoch 79/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6797e-05 - val_loss: 0.0024
# Epoch 80/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6589e-05 - val_loss: 0.0036
# Epoch 81/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.9976e-05 - val_loss: 0.0025
# Epoch 82/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7437e-05 - val_loss: 0.0028
# Epoch 83/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7017e-05 - val_loss: 0.0025
# Epoch 84/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7078e-05 - val_loss: 0.0051
# Epoch 85/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7425e-05 - val_loss: 0.0024
# Epoch 86/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6303e-05 - val_loss: 0.0028
# Epoch 87/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.8824e-05 - val_loss: 0.0030
# Epoch 88/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.1017e-05 - val_loss: 0.0050
# Epoch 89/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7453e-05 - val_loss: 0.0038
# Epoch 90/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.2640e-05 - val_loss: 0.0020
# Epoch 91/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.4276e-05 - val_loss: 0.0029
# Epoch 92/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6094e-05 - val_loss: 0.0023
# Epoch 93/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7174e-05 - val_loss: 0.0044
# Epoch 94/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.9135e-05 - val_loss: 0.0040
# Epoch 95/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5640e-05 - val_loss: 0.0027
# Epoch 96/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7190e-05 - val_loss: 0.0034
# Epoch 97/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5458e-05 - val_loss: 0.0021
# Epoch 98/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6120e-05 - val_loss: 0.0032
# Epoch 99/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6476e-05 - val_loss: 0.0034
# Epoch 100/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7093e-05 - val_loss: 0.0037
# Epoch 101/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.8609e-05 - val_loss: 0.0036
# Epoch 102/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6360e-05 - val_loss: 0.0035
# Epoch 103/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6468e-05 - val_loss: 0.0033
# Epoch 104/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6701e-05 - val_loss: 0.0020
# Epoch 105/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6259e-05 - val_loss: 0.0065
# Epoch 106/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.9715e-05 - val_loss: 0.0023
# Epoch 107/300
# 54/54 [==============================] - 0s 7ms/step - loss: 4.2665e-05 - val_loss: 0.0025
# Epoch 108/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6400e-05 - val_loss: 0.0021
# Epoch 109/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6028e-05 - val_loss: 0.0019
# Epoch 110/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7447e-05 - val_loss: 0.0020
# Epoch 111/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.3982e-05 - val_loss: 0.0036
# Epoch 112/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.8579e-05 - val_loss: 0.0030
# Epoch 113/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4234e-05 - val_loss: 0.0032
# Epoch 114/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4404e-05 - val_loss: 0.0021
# Epoch 115/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5270e-05 - val_loss: 0.0036
# Epoch 116/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5091e-05 - val_loss: 0.0021
# Epoch 117/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4946e-05 - val_loss: 0.0025
# Epoch 118/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.9085e-05 - val_loss: 0.0035
# Epoch 119/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5713e-05 - val_loss: 0.0051
# Epoch 120/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.9499e-05 - val_loss: 0.0027
# Epoch 121/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.3516e-05 - val_loss: 0.0027
# Epoch 122/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5376e-05 - val_loss: 0.0039
# Epoch 123/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5888e-05 - val_loss: 0.0029
# Epoch 124/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5049e-05 - val_loss: 0.0043
# Epoch 125/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6546e-05 - val_loss: 0.0029
# Epoch 126/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.6361e-05 - val_loss: 0.0023
# Epoch 127/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4638e-05 - val_loss: 0.0030
# Epoch 128/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.3860e-05 - val_loss: 0.0028
# Epoch 129/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.3946e-05 - val_loss: 0.0026
# Epoch 130/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.5529e-05 - val_loss: 0.0031
# Epoch 131/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3385e-05 - val_loss: 0.0031
# Epoch 132/300
# 54/54 [==============================] - 1s 14ms/step - loss: 3.5776e-05 - val_loss: 0.0033
# Epoch 133/300
# 54/54 [==============================] - 1s 10ms/step - loss: 3.4227e-05 - val_loss: 0.0038
# Epoch 134/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4429e-05 - val_loss: 0.0026
# Epoch 135/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.2879e-05 - val_loss: 0.0023
# Epoch 136/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.2705e-05 - val_loss: 0.0030
# Epoch 137/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.3349e-05 - val_loss: 0.0038
# Epoch 138/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.4230e-05 - val_loss: 0.0033
# Epoch 139/300
# 54/54 [==============================] - 0s 7ms/step - loss: 3.7846e-05 - val_loss: 0.0044
# Epoch 139: early stopping

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.ylim([0,0.01])
plt.show()
