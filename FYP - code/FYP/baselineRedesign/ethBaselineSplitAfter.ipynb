# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import math
from tensorflow.keras.utils import plot_model
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential 
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop
import os
from sklearn.metrics import mean_squared_error , mean_absolute_error , mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import LSTM , Dense , Dropout , GRU , Concatenate , Input , Conv1D , InputLayer
from tensorflow.keras import models
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# <Strong> Grabbing the data from stored files (originally pulled from Binance) </Strong>

# %%
df_eth = pd.read_csv("ETH_1h_data.csv")

# %%
df_eth
# Out:
#                           date     open     high      low    close  \
# 0      2017-08-17 04:00:00.000   301.13   302.57   298.00   301.61
# 1      2017-08-17 05:00:00.000   301.61   303.28   300.00   303.10
# 2      2017-08-17 06:00:00.000   302.40   304.44   301.90   302.68
# 3      2017-08-17 07:00:00.000   302.68   307.96   302.60   307.96
# 4      2017-08-17 08:00:00.000   307.95   309.97   307.00   308.62
# ...                        ...      ...      ...      ...      ...
# 39216      2022-02-11 10:00:00  3102.22  3115.98  3075.24  3106.33
# 39217      2022-02-11 11:00:00  3106.34  3109.86  3083.93  3088.30
# 39218      2022-02-11 12:00:00  3088.30  3122.00  3079.16  3102.23
# 39219      2022-02-11 13:00:00  3102.22  3127.00  3095.00  3121.64
# 39220      2022-02-11 14:00:00  3121.65  3128.20  3104.56  3110.51
#
#             volume
# 0        125.66877
# 1        377.67246
# 2        303.86672
# 3        754.74510
# 4        150.75029
# ...            ...
# 39216  12865.43100
# 39217   7796.24450
# 39218  13475.38960
# 39219  13585.96880
# 39220   5450.64810
#
# [39221 rows x 6 columns]

# %%
df_headers = df_eth.columns

# %% [markdown]
# <Strong> Grabbing the closing price (univariate) </Strong>

# %%
# Removing everything but the closing price
eth_data = df_eth.values[:, 4 ,].astype(float)

len(eth_data)
# Out:
# 39221

# %% [markdown]
# <Strong> Scaling the data  </Strong>

# %%
percTrain = 70
percVal = 20

onePercent = len(eth_data) // 100
numberTraining = onePercent * percTrain

scaler = MinMaxScaler()
reshaped_data = eth_data.reshape(-1,1)

#Just scaling on training data otherwise it would be leakage
scaler.fit(reshaped_data[:numberTraining])
scaled_eth = scaler.transform(reshaped_data)

# %% [markdown]
# <Strong> Creating Matrix in Sliding window form <Strong>

# %%
def sliding_window(elements, window_size):
    
    data = [] 
    targets = []
    
    if len(elements) <= window_size:
        return elements
    
    for i in range(len(elements) - window_size ):
        
        data.append(elements[i:i+window_size])
        targets.append(elements[i+window_size])
        
    return np.array(data) , np.array(targets)

# %%
window_length = 24
features = 1


sliding_winda_eth = sliding_window(scaled_eth , window_length)

# %% [markdown]
# <Strong> Splitting the data after we create Sliding Window matrix (more data) </Strong>

# %%
# Splitting the data after creating the sliding window data

def splitting_train_test(data):
        
    onePercent = len(data[1]) // 100
    
    numberTraining = onePercent * percTrain
    numberValidation = onePercent * percVal
    
    trainingData = data[0][:numberTraining] , data[1][:numberTraining]
    validationData = data[0][numberTraining : numberTraining + numberValidation] , data[1][numberTraining : numberTraining + numberValidation]
    testData = data[0][numberTraining + numberValidation:] , data[1][numberTraining + numberValidation:] 
    
    #Returning tuples of (sliding-window , target_values)
    return trainingData , validationData , testData

# %%
#Reshaping the data so we can use min-max a
eth_train , eth_val , eth_test = splitting_train_test(sliding_winda_eth)

print(eth_train[0].shape)
# Out:
# (27370, 24, 1)

# %% [markdown]
# <Strong> Creating the model </Strong>

# %%
inputs = Input(shape = (window_length , features) )

#From deep learning in python -- better to use recurrent dropout so error propergates correctly
x = LSTM(30 , return_sequences = True )(inputs)
x = Dropout(0.01)(x) 
x = LSTM(50)(x)
x = Dense(128)(x)

y = GRU(30,input_shape=(window_length , features))(inputs)
y = Dropout(0.01)(y)
y = Dense(128)(y)

final = Concatenate()([x,y])
final = Dense(1)(final)

model = tf.keras.Model(inputs=inputs, outputs= final)

model.summary()
plot_model(model)
# Out:
# 2022-03-08 16:08:47.538637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:47.632621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:47.633330: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:47.635022: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-08 16:08:47.638000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:47.638710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:47.639328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:49.877594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:49.878398: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:49.879042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-08 16:08:49.880769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13821 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 24, 1)]      0           []
#
#  lstm (LSTM)                    (None, 24, 30)       3840        ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 24, 30)       0           ['lstm[0][0]']
#
#  gru (GRU)                      (None, 30)           2970        ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 50)           16200       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 30)           0           ['gru[0][0]']
#
#  dense (Dense)                  (None, 128)          6528        ['lstm_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          3968        ['dropout_1[0][0]']
#
#  concatenate (Concatenate)      (None, 256)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            257         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 33,763
# Trainable params: 33,763
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# <Strong> Compiling the model </Strong>

# %%
model.compile(optimizer='adam' , loss = 'mse')

# %% [markdown]
# <Strong> Creating a callback to avail of early stopping </Strong>

# %%
earlyStopping = EarlyStopping(monitor = 'val_loss' , patience = 30 , mode = 'min' , verbose = 1)

# %% [markdown]
# <Strong> Training the model and storing the epoch where training stopped </Strong>

# %%
#Validation set needs to be in a tuple with x , y
history = model.fit(eth_train[0] , eth_train[1] , validation_data = eth_val  , batch_size = 512  , epochs =300 , verbose = 1 , callbacks = [earlyStopping] )
num_epochs = earlyStopping.stopped_epoch
# Out:
# Epoch 1/300
# 2022-03-08 16:08:56.229395: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 54/54 [==============================] - 10s 27ms/step - loss: 0.0054 - val_loss: 0.0182
# Epoch 2/300
# 54/54 [==============================] - 1s 16ms/step - loss: 5.6740e-05 - val_loss: 0.0153
# Epoch 3/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.8861e-05 - val_loss: 0.0160
# Epoch 4/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.8883e-05 - val_loss: 0.0146
# Epoch 5/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.7030e-05 - val_loss: 0.0156
# Epoch 6/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.6391e-05 - val_loss: 0.0166
# Epoch 7/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.4617e-05 - val_loss: 0.0158
# Epoch 8/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.4172e-05 - val_loss: 0.0147
# Epoch 9/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.5089e-05 - val_loss: 0.0131
# Epoch 10/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.3472e-05 - val_loss: 0.0159
# Epoch 11/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.4724e-05 - val_loss: 0.0130
# Epoch 12/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.1644e-05 - val_loss: 0.0139
# Epoch 13/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.1812e-05 - val_loss: 0.0124
# Epoch 14/300
# 54/54 [==============================] - 0s 8ms/step - loss: 4.0843e-05 - val_loss: 0.0112
# Epoch 15/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.9981e-05 - val_loss: 0.0108
# Epoch 16/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.8774e-05 - val_loss: 0.0121
# Epoch 17/300
# 54/54 [==============================] - 0s 9ms/step - loss: 3.8931e-05 - val_loss: 0.0103
# Epoch 18/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.9012e-05 - val_loss: 0.0104
# Epoch 19/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.7293e-05 - val_loss: 0.0090
# Epoch 20/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.6102e-05 - val_loss: 0.0099
# Epoch 21/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.7241e-05 - val_loss: 0.0085
# Epoch 22/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.6834e-05 - val_loss: 0.0088
# Epoch 23/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.6424e-05 - val_loss: 0.0097
# Epoch 24/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.5659e-05 - val_loss: 0.0084
# Epoch 25/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.4889e-05 - val_loss: 0.0080
# Epoch 26/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.5503e-05 - val_loss: 0.0060
# Epoch 27/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.6122e-05 - val_loss: 0.0054
# Epoch 28/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.4844e-05 - val_loss: 0.0072
# Epoch 29/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.5808e-05 - val_loss: 0.0060
# Epoch 30/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3268e-05 - val_loss: 0.0044
# Epoch 31/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3928e-05 - val_loss: 0.0065
# Epoch 32/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3344e-05 - val_loss: 0.0059
# Epoch 33/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3086e-05 - val_loss: 0.0062
# Epoch 34/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.2360e-05 - val_loss: 0.0057
# Epoch 35/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.2270e-05 - val_loss: 0.0043
# Epoch 36/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3676e-05 - val_loss: 0.0050
# Epoch 37/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3920e-05 - val_loss: 0.0049
# Epoch 38/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.2643e-05 - val_loss: 0.0048
# Epoch 39/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.2672e-05 - val_loss: 0.0046
# Epoch 40/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1928e-05 - val_loss: 0.0043
# Epoch 41/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1230e-05 - val_loss: 0.0041
# Epoch 42/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1897e-05 - val_loss: 0.0036
# Epoch 43/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1671e-05 - val_loss: 0.0048
# Epoch 44/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0657e-05 - val_loss: 0.0033
# Epoch 45/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3077e-05 - val_loss: 0.0027
# Epoch 46/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1369e-05 - val_loss: 0.0039
# Epoch 47/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0787e-05 - val_loss: 0.0027
# Epoch 48/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1372e-05 - val_loss: 0.0030
# Epoch 49/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1261e-05 - val_loss: 0.0032
# Epoch 50/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0127e-05 - val_loss: 0.0046
# Epoch 51/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1247e-05 - val_loss: 0.0029
# Epoch 52/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0711e-05 - val_loss: 0.0028
# Epoch 53/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1516e-05 - val_loss: 0.0037
# Epoch 54/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9747e-05 - val_loss: 0.0016
# Epoch 55/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0260e-05 - val_loss: 0.0043
# Epoch 56/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0640e-05 - val_loss: 0.0028
# Epoch 57/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0707e-05 - val_loss: 0.0022
# Epoch 58/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1063e-05 - val_loss: 0.0024
# Epoch 59/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8613e-05 - val_loss: 0.0029
# Epoch 60/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8643e-05 - val_loss: 0.0014
# Epoch 61/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9801e-05 - val_loss: 0.0019
# Epoch 62/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9766e-05 - val_loss: 0.0022
# Epoch 63/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0477e-05 - val_loss: 0.0017
# Epoch 64/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8550e-05 - val_loss: 0.0012
# Epoch 65/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.6847e-05 - val_loss: 0.0023
# Epoch 66/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.2364e-05 - val_loss: 0.0020
# Epoch 67/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9926e-05 - val_loss: 0.0026
# Epoch 68/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.2163e-05 - val_loss: 0.0019
# Epoch 69/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9949e-05 - val_loss: 0.0016
# Epoch 70/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1007e-05 - val_loss: 0.0016
# Epoch 71/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8830e-05 - val_loss: 0.0024
# Epoch 72/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9156e-05 - val_loss: 0.0017
# Epoch 73/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8124e-05 - val_loss: 0.0014
# Epoch 74/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0141e-05 - val_loss: 0.0019
# Epoch 75/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0202e-05 - val_loss: 0.0015
# Epoch 76/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8347e-05 - val_loss: 0.0019
# Epoch 77/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1825e-05 - val_loss: 0.0016
# Epoch 78/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7502e-05 - val_loss: 0.0011
# Epoch 79/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9482e-05 - val_loss: 7.2317e-04
# Epoch 80/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1524e-05 - val_loss: 0.0013
# Epoch 81/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0962e-05 - val_loss: 0.0011
# Epoch 82/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1133e-05 - val_loss: 0.0020
# Epoch 83/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1597e-05 - val_loss: 0.0024
# Epoch 84/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8237e-05 - val_loss: 0.0014
# Epoch 85/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1823e-05 - val_loss: 0.0019
# Epoch 86/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8457e-05 - val_loss: 0.0018
# Epoch 87/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7727e-05 - val_loss: 9.0660e-04
# Epoch 88/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0568e-05 - val_loss: 0.0017
# Epoch 89/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7540e-05 - val_loss: 0.0014
# Epoch 90/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1399e-05 - val_loss: 0.0019
# Epoch 91/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8329e-05 - val_loss: 0.0011
# Epoch 92/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8375e-05 - val_loss: 6.6319e-04
# Epoch 93/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9878e-05 - val_loss: 0.0013
# Epoch 94/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3512e-05 - val_loss: 0.0016
# Epoch 95/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0136e-05 - val_loss: 0.0012
# Epoch 96/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7880e-05 - val_loss: 0.0010
# Epoch 97/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3671e-05 - val_loss: 0.0015
# Epoch 98/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7933e-05 - val_loss: 0.0010
# Epoch 99/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0717e-05 - val_loss: 0.0019
# Epoch 100/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1002e-05 - val_loss: 0.0013
# Epoch 101/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7390e-05 - val_loss: 9.0650e-04
# Epoch 102/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8706e-05 - val_loss: 0.0018
# Epoch 103/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7601e-05 - val_loss: 0.0014
# Epoch 104/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8426e-05 - val_loss: 0.0015
# Epoch 105/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1653e-05 - val_loss: 6.7163e-04
# Epoch 106/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9548e-05 - val_loss: 0.0020
# Epoch 107/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7784e-05 - val_loss: 6.5325e-04
# Epoch 108/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.8931e-05 - val_loss: 7.4598e-04
# Epoch 109/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7126e-05 - val_loss: 0.0019
# Epoch 110/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6318e-05 - val_loss: 0.0021
# Epoch 111/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9512e-05 - val_loss: 0.0013
# Epoch 112/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8598e-05 - val_loss: 0.0014
# Epoch 113/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8356e-05 - val_loss: 7.2918e-04
# Epoch 114/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0123e-05 - val_loss: 0.0030
# Epoch 115/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0226e-05 - val_loss: 9.3966e-04
# Epoch 116/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3452e-05 - val_loss: 0.0011
# Epoch 117/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8787e-05 - val_loss: 0.0012
# Epoch 118/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5709e-05 - val_loss: 0.0011
# Epoch 119/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6464e-05 - val_loss: 8.4472e-04
# Epoch 120/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8255e-05 - val_loss: 0.0014
# Epoch 121/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8860e-05 - val_loss: 0.0016
# Epoch 122/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9627e-05 - val_loss: 0.0034
# Epoch 123/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3088e-05 - val_loss: 0.0012
# Epoch 124/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0037e-05 - val_loss: 7.8746e-04
# Epoch 125/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6747e-05 - val_loss: 0.0013
# Epoch 126/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7451e-05 - val_loss: 0.0010
# Epoch 127/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8959e-05 - val_loss: 7.4960e-04
# Epoch 128/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7363e-05 - val_loss: 0.0013
# Epoch 129/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7298e-05 - val_loss: 0.0015
# Epoch 130/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7550e-05 - val_loss: 0.0011
# Epoch 131/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8412e-05 - val_loss: 8.6073e-04
# Epoch 132/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6445e-05 - val_loss: 0.0012
# Epoch 133/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6638e-05 - val_loss: 0.0012
# Epoch 134/300
# 54/54 [==============================] - 1s 15ms/step - loss: 2.8235e-05 - val_loss: 7.8103e-04
# Epoch 135/300
# 54/54 [==============================] - 1s 11ms/step - loss: 3.0969e-05 - val_loss: 7.5312e-04
# Epoch 136/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0104e-05 - val_loss: 5.7403e-04
# Epoch 137/300
# 54/54 [==============================] - 0s 9ms/step - loss: 2.9153e-05 - val_loss: 6.5929e-04
# Epoch 138/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.1371e-05 - val_loss: 7.3331e-04
# Epoch 139/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7812e-05 - val_loss: 7.1514e-04
# Epoch 140/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5903e-05 - val_loss: 7.9016e-04
# Epoch 141/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0909e-05 - val_loss: 0.0012
# Epoch 142/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9089e-05 - val_loss: 8.5406e-04
# Epoch 143/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6925e-05 - val_loss: 0.0023
# Epoch 144/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0321e-05 - val_loss: 5.5702e-04
# Epoch 145/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6483e-05 - val_loss: 0.0013
# Epoch 146/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0098e-05 - val_loss: 0.0010
# Epoch 147/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.9280e-05 - val_loss: 0.0017
# Epoch 148/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7924e-05 - val_loss: 0.0013
# Epoch 149/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7111e-05 - val_loss: 7.0404e-04
# Epoch 150/300
# 54/54 [==============================] - 0s 9ms/step - loss: 2.6862e-05 - val_loss: 5.9844e-04
# Epoch 151/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8429e-05 - val_loss: 0.0020
# Epoch 152/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8508e-05 - val_loss: 0.0017
# Epoch 153/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5338e-05 - val_loss: 0.0019
# Epoch 154/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.3104e-05 - val_loss: 7.9282e-04
# Epoch 155/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8029e-05 - val_loss: 9.9953e-04
# Epoch 156/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5766e-05 - val_loss: 9.3218e-04
# Epoch 157/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7956e-05 - val_loss: 0.0011
# Epoch 158/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7709e-05 - val_loss: 0.0021
# Epoch 159/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0702e-05 - val_loss: 0.0017
# Epoch 160/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7508e-05 - val_loss: 0.0011
# Epoch 161/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7028e-05 - val_loss: 6.5900e-04
# Epoch 162/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6386e-05 - val_loss: 0.0014
# Epoch 163/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7315e-05 - val_loss: 0.0024
# Epoch 164/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7609e-05 - val_loss: 0.0017
# Epoch 165/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.6619e-05 - val_loss: 0.0014
# Epoch 166/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5972e-05 - val_loss: 7.2735e-04
# Epoch 167/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8039e-05 - val_loss: 0.0015
# Epoch 168/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5385e-05 - val_loss: 8.1060e-04
# Epoch 169/300
# 54/54 [==============================] - 0s 9ms/step - loss: 2.6949e-05 - val_loss: 0.0010
# Epoch 170/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.7481e-05 - val_loss: 0.0027
# Epoch 171/300
# 54/54 [==============================] - 0s 8ms/step - loss: 3.0424e-05 - val_loss: 0.0011
# Epoch 172/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5613e-05 - val_loss: 0.0015
# Epoch 173/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.5776e-05 - val_loss: 0.0017
# Epoch 174/300
# 54/54 [==============================] - 0s 8ms/step - loss: 2.8799e-05 - val_loss: 0.0018
# Epoch 174: early stopping

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.ylim([0,0.02])
plt.show()

# %% [markdown]
# <Strong> Testing on the validation data once again , hyper-parameter adjustment. <Strong>

# %%
validation_predict = model.predict(eth_val[0])
validation_predict = scaler.inverse_transform(validation_predict)

validation_actual = scaler.inverse_transform(eth_val[1])
math.sqrt(mean_squared_error(validation_actual , validation_predict))
# Out:
# 56.87838546599425

# %% [markdown]
# <Strong> Combining the train and validation set when perfected hyper-parameters and training on fresh model. </Strong>

# %%
train_and_val = np.concatenate([eth_train[0] , eth_val[0]] )
train_and_val_targets = np.concatenate([eth_train[1] , eth_val[1] ])

freshModel = tf.keras.Model(inputs=inputs, outputs= final)
freshModel.compile(optimizer='adam' , loss = 'mse')

final = freshModel.fit(train_and_val , train_and_val_targets , batch_size = 512  , epochs = num_epochs , verbose = 1 )
# Out:
# Epoch 1/173
# 69/69 [==============================] - 4s 8ms/step - loss: 3.0992e-04
# Epoch 2/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5651e-04
# Epoch 3/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6212e-04
# Epoch 4/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.7087e-04
# Epoch 5/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5618e-04
# Epoch 6/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5204e-04
# Epoch 7/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5821e-04
# Epoch 8/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4816e-04
# Epoch 9/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6338e-04
# Epoch 10/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5366e-04
# Epoch 11/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6077e-04
# Epoch 12/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4553e-04
# Epoch 13/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4822e-04
# Epoch 14/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5220e-04
# Epoch 15/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.7674e-04
# Epoch 16/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4181e-04
# Epoch 17/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3821e-04
# Epoch 18/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.9555e-04
# Epoch 19/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5035e-04
# Epoch 20/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6216e-04
# Epoch 21/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5063e-04
# Epoch 22/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.7276e-04
# Epoch 23/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5111e-04
# Epoch 24/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4207e-04
# Epoch 25/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6248e-04
# Epoch 26/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3741e-04
# Epoch 27/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4331e-04
# Epoch 28/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4151e-04
# Epoch 29/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4772e-04
# Epoch 30/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5875e-04
# Epoch 31/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4402e-04
# Epoch 32/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5157e-04
# Epoch 33/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5264e-04
# Epoch 34/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6831e-04
# Epoch 35/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5125e-04
# Epoch 36/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5292e-04
# Epoch 37/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4999e-04
# Epoch 38/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4381e-04
# Epoch 39/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4927e-04
# Epoch 40/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3650e-04
# Epoch 41/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3118e-04
# Epoch 42/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3024e-04
# Epoch 43/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3853e-04
# Epoch 44/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3753e-04
# Epoch 45/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3714e-04
# Epoch 46/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2731e-04
# Epoch 47/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4046e-04
# Epoch 48/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3429e-04
# Epoch 49/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5526e-04
# Epoch 50/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5534e-04
# Epoch 51/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5215e-04
# Epoch 52/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2937e-04
# Epoch 53/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3094e-04
# Epoch 54/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4465e-04
# Epoch 55/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3373e-04
# Epoch 56/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4708e-04
# Epoch 57/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3726e-04
# Epoch 58/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3815e-04
# Epoch 59/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3941e-04
# Epoch 60/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3583e-04
# Epoch 61/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2491e-04
# Epoch 62/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3962e-04
# Epoch 63/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5265e-04
# Epoch 64/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3048e-04
# Epoch 65/173
# 69/69 [==============================] - 1s 7ms/step - loss: 1.4218e-04
# Epoch 66/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4284e-04
# Epoch 67/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4799e-04
# Epoch 68/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4035e-04
# Epoch 69/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2661e-04
# Epoch 70/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2196e-04
# Epoch 71/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3284e-04
# Epoch 72/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2291e-04
# Epoch 73/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3114e-04
# Epoch 74/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3542e-04
# Epoch 75/173
# 69/69 [==============================] - 1s 8ms/step - loss: 1.2333e-04
# Epoch 76/173
# 69/69 [==============================] - 1s 12ms/step - loss: 1.3062e-04
# Epoch 77/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3435e-04
# Epoch 78/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3572e-04
# Epoch 79/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3246e-04
# Epoch 80/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2812e-04
# Epoch 81/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2830e-04
# Epoch 82/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4356e-04
# Epoch 83/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3019e-04
# Epoch 84/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3410e-04
# Epoch 85/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3129e-04
# Epoch 86/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3056e-04
# Epoch 87/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3035e-04
# Epoch 88/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2537e-04
# Epoch 89/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3098e-04
# Epoch 90/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2450e-04
# Epoch 91/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2712e-04
# Epoch 92/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2465e-04
# Epoch 93/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3190e-04
# Epoch 94/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3410e-04
# Epoch 95/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5914e-04
# Epoch 96/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3546e-04
# Epoch 97/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4060e-04
# Epoch 98/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2068e-04
# Epoch 99/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2604e-04
# Epoch 100/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2648e-04
# Epoch 101/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2941e-04
# Epoch 102/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3428e-04
# Epoch 103/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.5235e-04
# Epoch 104/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2241e-04
# Epoch 105/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2545e-04
# Epoch 106/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2987e-04
# Epoch 107/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3786e-04
# Epoch 108/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3519e-04
# Epoch 109/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3703e-04
# Epoch 110/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1734e-04
# Epoch 111/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3525e-04
# Epoch 112/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3213e-04
# Epoch 113/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2018e-04
# Epoch 114/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2315e-04
# Epoch 115/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.6489e-04
# Epoch 116/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2097e-04
# Epoch 117/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2711e-04
# Epoch 118/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2692e-04
# Epoch 119/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2956e-04
# Epoch 120/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3777e-04
# Epoch 121/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1985e-04
# Epoch 122/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2114e-04
# Epoch 123/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2189e-04
# Epoch 124/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2609e-04
# Epoch 125/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2377e-04
# Epoch 126/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2288e-04
# Epoch 127/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3499e-04
# Epoch 128/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2707e-04
# Epoch 129/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1564e-04
# Epoch 130/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2440e-04
# Epoch 131/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1712e-04
# Epoch 132/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2748e-04
# Epoch 133/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2508e-04
# Epoch 134/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3208e-04
# Epoch 135/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3740e-04
# Epoch 136/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2357e-04
# Epoch 137/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1503e-04
# Epoch 138/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3103e-04
# Epoch 139/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1932e-04
# Epoch 140/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2237e-04
# Epoch 141/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3574e-04
# Epoch 142/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3239e-04
# Epoch 143/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2602e-04
# Epoch 144/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1653e-04
# Epoch 145/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1784e-04
# Epoch 146/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2848e-04
# Epoch 147/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4605e-04
# Epoch 148/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3009e-04
# Epoch 149/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1652e-04
# Epoch 150/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3530e-04
# Epoch 151/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2687e-04
# Epoch 152/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3202e-04
# Epoch 153/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3217e-04
# Epoch 154/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1851e-04
# Epoch 155/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.3515e-04
# Epoch 156/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2217e-04
# Epoch 157/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1915e-04
# Epoch 158/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2928e-04
# Epoch 159/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1687e-04
# Epoch 160/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2497e-04
# Epoch 161/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4887e-04
# Epoch 162/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1271e-04
# Epoch 163/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1803e-04
# Epoch 164/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2929e-04
# Epoch 165/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1944e-04
# Epoch 166/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1855e-04
# Epoch 167/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2536e-04
# Epoch 168/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1833e-04
# Epoch 169/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1824e-04
# Epoch 170/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2875e-04
# Epoch 171/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4575e-04
# Epoch 172/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.1967e-04
# Epoch 173/173
# 69/69 [==============================] - 0s 7ms/step - loss: 1.2639e-04

# %% [markdown]
# <Strong> Finally testing on test set and grabbing evaluation metrics </Strong>

# %%
test_predict = freshModel.predict(eth_test[0])
test_predict = scaler.inverse_transform(test_predict)
test_actual = scaler.inverse_transform(eth_test[1])

# %%
print(math.sqrt(mean_absolute_error(test_actual , test_predict)))
print(math.sqrt(mean_absolute_percentage_error(test_actual , test_predict)))
print(math.sqrt(mean_squared_error(test_actual , test_predict , squared = False)))
print(math.sqrt(mean_squared_error(test_actual , test_predict)))
# Out:
# 6.862579127527321
# 0.11235363078672028
# 7.450655145008023
# 55.512262089834515

# %% [markdown]
# <Strong> For Predicting more than 1 day in the future - Test Set. </Strong>

# %%
def steps_in_future(hours_in_future , data):
    
    #All the hours_in_future time predictions
    predictions = []
    
    # Have to cut off the (hours_in_future - 1) off the test set to avoid out of bounds error
    test_data = data[0][:-(hours_in_future - 1)]
    
    for x in range (len(test_data)):
        #Going through all the windows
        last_window = test_data[x].reshape(1,-1)
    
            # Make as many predictions as hours_in_future
        for i in range(hours_in_future):
            
            # Take the predicted value from the last window in training set
            last_prediction = model.predict(last_window)[0]

            #shifting the window size one step down
            last_window[0] = np.roll(last_window[0], -1)

            #replacing the old value with new prediction
            last_window[0 , (len(last_window[0]) - 1)] = last_prediction

        #append prediction
        predictions.append(last_prediction)
    
    return predictions

# %%
three_day_predictions = steps_in_future(3, eth_test)
seven_day_predictions = steps_in_future( 7, eth_test)

# %%
scaled_three_day_predictions = scaler.inverse_transform(three_day_predictions)
scaled_seven_day_predictions = scaler.inverse_transform(seven_day_predictions)

# %%
# Targets to compare  
targets_in_future_three = eth_test[1][(3 - 1):]
targets_in_future_three = scaler.inverse_transform(targets_in_future_three)

targets_in_future_seven = eth_test[1][(7 - 1):]
targets_in_future_seven = scaler.inverse_transform(targets_in_future_seven)

# %%
print(math.sqrt(mean_absolute_error(targets_in_future_three , scaled_three_day_predictions)))
#print(math.sqrt(mean_absolute_error(targets_in_future_seven , scaled_seven_day_predictions)))

print(math.sqrt(mean_squared_error(targets_in_future_three , scaled_three_day_predictions )))
#print(math.sqrt(mean_squared_error(targets_in_future_seven , scaled_seven_day_predictions )))

print(math.sqrt(mean_squared_error(targets_in_future_three , scaled_three_day_predictions , squared = False)))
#print(math.sqrt(mean_squared_error(targets_in_future_seven , scaled_seven_day_predictions , squared = False)))

print(math.sqrt(mean_absolute_percentage_error(targets_in_future_three , scaled_three_day_predictions)))
#print(math.sqrt(mean_absolute_percentage_error(targets_in_future_seven , scaled_seven_day_predictions)))
# Out:
# 10.966559132813941
# 133.87429421036944
# 11.570405965668163
# 0.17923261223487785
